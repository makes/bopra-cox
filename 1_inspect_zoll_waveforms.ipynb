# %% [markdown]
# # BOPRA data preparation
#
# Simo Mäkelä
# Helsinki Metropolia University of Applied Sciences
# 1.10.2020

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt

from utils import zoll
from utils import misc
from utils.autoscale import autoscale

# %%
# parameters
case_id = 1

# %%
case_str = str(case_id).zfill(5)
zoll_filename = 'zoll' + case_str + '.json'
json = zoll.LoadJSON("data/" + zoll_filename)

# %%
def zoomed_plot(df, samplerate, start=900, end=910):
    duration = len(df) / samplerate
    if duration < 10:
        print("Nothing to plot.")
        return
    time = np.arange(0, duration, 1 / samplerate) # time vector

    fig = plt.figure(figsize=(20,4))
    ax = plt.gca()
    plt.xlim(start, end)
    plt.title("10 seconds of waveform")
    plt.plot(time, df['Waveform'].tolist(), color="red")
    autoscale(ax, 'y')
    plt.show()

# %% [markdown]
# ## Channel 0:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=0)
# Out:
# Channel 0: Pads
# WaveType:  1
# Duration:             0.0 s
# Total samples:          0      Discarded:       0
# Sample rate:          250 1/s  Sample time:  4000 μs

# %%
df.plot(figsize=(20,4), title="Channel 0")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e94504580&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# Nothing to plot.

# %% [markdown]
# ## Channel 1:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=1)
# Out:
# Channel 1: CO2 kPa, Waveform
# WaveType:  48
# Duration:         4050.12 s
# Total samples:     506265      Discarded:   23404
# Sample rate:          125 1/s  Sample time:  8000 μs
# Min:                 -227      Max:           339

# %%
df.plot(figsize=(20,4), title="Channel 1")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e948c9760&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %% [markdown]
# ## Channel 2:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=2)
# Out:
# Channel 2: IBP 1 mmHg, Waveform
# WaveType:  18
# Duration:            0.36 s
# Total samples:         45      Discarded:     189
# Sample rate:          125 1/s  Sample time:  8000 μs

# %%
df.plot(figsize=(20,4), title="Channel 2")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e96fccf10&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# Nothing to plot.

# %% [markdown]
# ## Channel 3:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=3)
# Out:
# Channel 3: IBP 2 mmHg, Waveform
# WaveType:  19
# Duration:            0.12 s
# Total samples:         15      Discarded:      55
# Sample rate:          125 1/s  Sample time:  8000 μs

# %%
df.plot(figsize=(20,4), title="Channel 3")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e96fe9b80&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# Nothing to plot.

# %% [markdown]
# ## Channel 4:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=4)
# Out:
# Channel 4: IBP 3 mmHg, Waveform
# WaveType:  20
# Duration:            0.12 s
# Total samples:         15      Discarded:      55
# Sample rate:          125 1/s  Sample time:  8000 μs

# %%
df.plot(figsize=(20,4), title="Channel 4")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e972db160&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# Nothing to plot.

# %% [markdown]
# ## Channel 5:

# %%
df, samplerate = zoll.LoadWaveform(json, hide_starttime=True, channel=5)
# Out:
# Channel 5: Pads Impedance
# WaveType:  23
# Duration:             0.0 s
# Total samples:          0      Discarded:       0
# Sample rate:          125 1/s  Sample time:  8000 μs

# %%
df.plot(figsize=(20,4), title="Channel 5")
# Out:
# &lt;matplotlib.axes._subplots.AxesSubplot at 0x29e9731a460&gt;
# &lt;Figure size 1440x288 with 1 Axes&gt;

# %%
zoomed_plot(df, samplerate)
# Out:
# Nothing to plot.
